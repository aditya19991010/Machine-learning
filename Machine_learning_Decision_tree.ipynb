# %%
#Y, dependent variable - target variable
#x, vector --> composed of the features


#Prepare a training data for credit giving by bank

import sys
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree
from matplotlib import pyplot as plt
from sklearn import datasets

# %%
cd Decision\ Tree\ in\ Python
# Out:
# /home/lgi/Desktop/Decision Tree in Python

# %%
cat 'Decision_Tree_ Dataset.csv'
# Out:
# ﻿1,2,3,4,sum,
# 201,10018,250,3046,13515,yes
# 205,10016,395,3044,13660,yes
# 257,10129,109,3251,13746,yes
# 246,10064,324,3137,13771,yes
# 117,10115,496,3094,13822,yes
# 406,10187,166,3068,13827,yes
# 461,10252,172,3062,13947,yes
# 158,10192,144,3469,13963,yes
# 136,10376,230,3223,13965,yes
# 194,10092,626,3083,13995,yes
# 427,10404,137,3029,13997,yes
# 151,10203,411,3257,14022,yes
# 338,10074,432,3246,14090,yes
# 362,10403,257,3073,14095,yes
# 108,10451,336,3238,14133,yes
# 315,10005,302,3516,14138,yes
# 193,10289,629,3040,14151,yes
# 279,10308,199,3426,14212,yes
# 120,10198,233,3665,14216,yes
# 246,10176,717,3079,14218,yes
# 226,10232,659,3105,14222,yes
# 115,10167,538,3426,14246,yes
# 497,10057,475,3253,14282,yes
# 449,10284,512,3044,14289,yes
# 289,10127,140,3742,14298,yes
# 313,10555,178,3272,14318,yes
# 411,10126,272,3518,14327,yes
# 244,10665,246,3195,14350,yes
# 228,10080,401,3642,14351,yes
# 274,10452,603,3024,14353,yes
# 366,10026,139,3827,14358,yes
# ...

# %%
dataset = pd.read_csv('Decision_Tree_ Dataset.csv', sep=',', header=0).iloc[:,0:6] #sep strands for separator

# %% [raw]
# header :
#     Row number(s) to use as the column names, and the start of the
#     data.  Default behavior is to infer the column names: if no names
#     are passed the behavior is identical to ``header=0`` and column
#     names are inferred from the first line of the file, if column
#     names are passed explicitly then the behavior is identical to
#     ``header=None``. Explicitly pass ``header=0`` to be able to
#     replace existing names.

# %%
dataset.head()
# Out:
#      1      2    3     4    sum Unnamed: 5
# 0  201  10018  250  3046  13515        yes
# 1  205  10016  395  3044  13660        yes
# 2  257  10129  109  3251  13746        yes
# 3  246  10064  324  3137  13771        yes
# 4  117  10115  496  3094  13822        yes

# %%
dataset.describe()
# Out:
#                 1            2            3            4           sum
# count  1000.00000   1000.00000  1000.000000  1000.000000   1000.000000
# mean    294.34300  12465.88400   528.042000  4027.011000  17315.280000
# std     115.81539   1440.15617   259.796059   565.164179   1589.943875
# min     100.00000  10005.00000   100.000000  3003.000000  13515.000000
# 25%     195.00000  11201.50000   302.000000  3545.000000  16073.750000
# 50%     289.50000  12450.00000   516.500000  4041.500000  17383.000000
# 75%     398.00000  13678.25000   753.500000  4507.000000  18595.250000
# max     500.00000  14996.00000   997.000000  5000.000000  20737.000000

# %%
dataset
# Out:
#        1      2    3     4    sum Unnamed: 5
# 0    201  10018  250  3046  13515        yes
# 1    205  10016  395  3044  13660        yes
# 2    257  10129  109  3251  13746        yes
# 3    246  10064  324  3137  13771        yes
# 4    117  10115  496  3094  13822        yes
# ..   ...    ...  ...   ...    ...        ...
# 995  413  14914  523  4683  20533         No
# 996  359  14423  927  4838  20547         No
# 997  316  14872  613  4760  20561         No
# 998  305  14926  897  4572  20700         No
# 999  168  14798  834  4937  20737         No
#
# [1000 rows x 6 columns]

# %%
dataset.shape #shows rows, columns
# Out:
# (1000, 6)

# %%
dataset.head()
# Out:
#      1      2    3     4    sum Unnamed: 5
# 0  201  10018  250  3046  13515        yes
# 1  205  10016  395  3044  13660        yes
# 2  257  10129  109  3251  13746        yes
# 3  246  10064  324  3137  13771        yes
# 4  117  10115  496  3094  13822        yes

# %% [markdown]
# ### Renaming

# %%
dataset.rename(columns = {'1':'initial_payment'}, inplace = True)
dataset.rename(columns = {'2':'last_payment'}, inplace = True)
dataset.rename(columns = {'3':'credit_score'}, inplace = True)
dataset.rename(columns = {'4':'house_number'}, inplace = True)
dataset.rename(columns = {'Unnamed: 5':'result'}, inplace = True)

# %%
dataset.head()
# Out:
#    initial_payment  last_payment  credit_score  house_number    sum result
# 0              201         10018           250          3046  13515    yes
# 1              205         10016           395          3044  13660    yes
# 2              257         10129           109          3251  13746    yes
# 3              246         10064           324          3137  13771    yes
# 4              117         10115           496          3094  13822    yes

# %% [markdown]
# ## Training data

# %%
#Seprating target variables

X = dataset.values[:, 0:4]
y = dataset.values[:, 5]

# %%
#Splitting dataset into test and train
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
#Function to perform training with entropy

clf_entropy = DecisionTreeClassifier(criterion= "entropy", random_state= 100, max_depth=6, min_samples_leaf=5,)
#max_depth = shows the 3 layers of decision making

clf_entropy.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6, min_samples_leaf=5,
#                        random_state=100)

# %%
y_pred_en = clf_entropy.predict(X_test)

# %% [markdown]
# ### Check accuracy

# %%
accuracy_score(y_test,y_pred_en)
# Out:
# 0.9363636363636364

# %%
clf_entropy.decision_path(X)
# Out:
# <1000x27 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3867 stored elements in Compressed Sparse Row format>

# %%
text_representation = tree.export_text(clf_entropy)

# %%
print(text_representation)
# Out:
# |--- feature_1 <= 12402.50
# |   |--- feature_1 <= 11433.00
# |   |   |--- class: yes
# |   |--- feature_1 >  11433.00
# |   |   |--- feature_3 <= 4070.50
# |   |   |   |--- feature_2 <= 959.00
# |   |   |   |   |--- class: yes
# |   |   |   |--- feature_2 >  959.00
# |   |   |   |   |--- class: yes
# |   |   |--- feature_3 >  4070.50
# |   |   |   |--- feature_2 <= 658.50
# |   |   |   |   |--- feature_3 <= 4729.50
# |   |   |   |   |   |--- feature_1 <= 12267.00
# |   |   |   |   |   |   |--- class: yes
# |   |   |   |   |   |--- feature_1 >  12267.00
# |   |   |   |   |   |   |--- class: No
# |   |   |   |   |--- feature_3 >  4729.50
# |   |   |   |   |   |--- feature_1 <= 11977.50
# |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- feature_1 >  11977.50
# |   |   |   |   |   |   |--- class: No
# |   |   |   |--- feature_2 >  658.50
# |   |   |   |   |--- class: No
# |--- feature_1 >  12402.50
# |   |--- feature_1 <= 13281.50
# |   |   |--- feature_3 <= 3807.00
# ...

# %%
fig_tree = plt.figure(figsize=(10,10))
tree.plot_tree(clf_entropy, filled=True, feature_names= dataset.feature_names)
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 2
#       1 fig_tree = plt.figure(figsize=(10,10))
# ----> 2 tree.plot_tree(clf_entropy, filled=True, feature_names= dataset.feature_names)
#       3 plt.show
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'feature_names'

# %%
import graphlib

# %%
from dtreeviz.trees import *

# %%
from dtreeviz.models import sklearn_decision_trees

# %%
tree.plot_tree(clf_entropy, feature_names= dataset.result, filled=True)
